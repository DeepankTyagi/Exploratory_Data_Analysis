# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data (1).csv",index_col='date')

# %%
df.head(5)
# Out:
#             price
# date
# 1950-01-01  34.73
# 1950-02-01  34.73
# 1950-03-01  34.73
# 1950-04-01  34.73
# 1950-05-01  34.73

# %%
df.tail(5)
# Out:
#                price
# date
# 2017-10-01  1280.677
# 2017-11-01  1283.189
# 2017-12-01  1265.674
# 2018-01-01  1332.809
# 2018-02-01  1333.775

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 818 entries, 1950-01-01 to 2018-02-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   818 non-null    float64
# dtypes: float64(1)
# memory usage: 12.8+ KB

# %%
sns.scatterplot(data=df)
# Out:
# <Axes: xlabel='date'>

# %%
df.shape
# Out:
# (818, 1)

# %%
df2=df.iloc[-120:,:]

# %%
df2
# Out:
#                price
# date
# 2008-03-01   971.055
# 2008-04-01   911.600
# 2008-05-01   889.125
# 2008-06-01   889.536
# 2008-07-01   941.167
# ...              ...
# 2017-10-01  1280.677
# 2017-11-01  1283.189
# 2017-12-01  1265.674
# 2018-01-01  1332.809
# 2018-02-01  1333.775
#
# [120 rows x 1 columns]

# %%
df.plot(figsize=(12,8))               # a pandas command
# Out:
# <Axes: xlabel='date'>

# %%
df2.index.freq="MS"
df2.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='date'>

# %%
datayearly=df2.rolling(window=12).mean()

# %%
datayearly.plot(title="Yearly Average Price")
# Out:
# <Axes: title={'center': 'Yearly Average Price'}, xlabel='date'>
